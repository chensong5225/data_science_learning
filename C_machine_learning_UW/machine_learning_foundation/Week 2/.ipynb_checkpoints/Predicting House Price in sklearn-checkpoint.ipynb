# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
sales = pd.read_csv('home_data.csv')
sales.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
sales.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
from sklearn.model_selection import train_test_split
target = sales.price
x_train, x_test, y_train, y_test = train_test_split(sales, target, train_size=0.8, random_state=0)
# Out:
# /Users/chensong/anaconda/envs/python2/lib/python2.7/site-packages/sklearn/model_selection/_split.py:2010: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import math
x_train_sqft = x_train.sqft_living
x_test_sqft = x_test.sqft_living
sqft_model = LinearRegression().fit(x_train_sqft.reshape(-1, 1), y_train)
y_pred = sqft_model.predict(x_test_sqft.reshape(-1, 1))
print math.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 248879.061436
# /Users/chensong/anaconda/envs/python2/lib/python2.7/site-packages/ipykernel_launcher.py:6: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#
# /Users/chensong/anaconda/envs/python2/lib/python2.7/site-packages/ipykernel_launcher.py:7: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   import sys

# %%
plt.plot(x_test_sqft,y_test,'.', x_test_sqft,y_pred,'-')

# %%
print sqft_model.intercept_, sqft_model.coef_
# Out:
# -48257.0634556 [ 283.96855737]

# %%
my_features = ['bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode']
x_train_my = x_train[my_features]
x_test_my = x_test[my_features]

my_model = LinearRegression().fit(x_train_my, y_train)
y_pred = my_model.predict(x_test_my)
print math.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 244004.774431

# %%
house1 = sales[sales.id==5309101200]
print house1['price']
print sqft_model.predict(house1.sqft_living.reshape(-1, 1))
print my_model.predict(house1[my_features])
# Out:
# 1054    620000
# Name: price, dtype: int64
# [ 633267.47422744]
# [ 637556.26515923]
# /Users/chensong/anaconda/envs/python2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
house2 = sales[sales.id==1925069082]
print house2['price']
print sqft_model.predict(house2.sqft_living.reshape(-1, 1))
print my_model.predict(house2[my_features])
# Out:
# 1361    2200000
# Name: price, dtype: int64
# [ 1269357.04273158]
# [ 1274443.76531348]
# /Users/chensong/anaconda/envs/python2/lib/python2.7/site-packages/ipykernel_launcher.py:3: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   This is separate from the ipykernel package so we can avoid doing imports until
